# %%
! curl -s https://packagecloud.io/install/repositories/github/git-lfs/script.deb.sh | sudo bash
! sudo apt-get install git-lfs
! git lfs install
! git clone https://github.com/neheller/kits19.git
# Out:
# Detected operating system as Ubuntu/bionic.
# Checking for curl...
# Detected curl...
# Checking for gpg...
# Detected gpg...
# Running apt-get update... done.
# Installing apt-transport-https... done.
# Installing /etc/apt/sources.list.d/github_git-lfs.list...done.
# Importing packagecloud gpg key... done.
# Running apt-get update... done.
#
# The repository is setup! You can now install packages.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git-lfs is already the newest version (2.11.0).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 46 not upgraded.
# Git LFS initialized.
# fatal: destination path 'kits19' already exists and is not an empty directory.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd kits19
! python -m starter_code.get_imaging
# Out:
# /content/kits19
# 300 cases to download...
# Download 1/300:
# case_00000: 100% 225959/225960 [00:04<00:00, 55267.15KB/s]
# Download 2/300:
# case_00001: 100% 276387/276388 [00:04<00:00, 57938.97KB/s]
# Download 3/300:
# case_00002: 100% 101967/101968 [00:03<00:00, 28887.52KB/s]
# Download 4/300:
# case_00003: 100% 118681/118682 [00:02<00:00, 53418.36KB/s]
# Download 5/300:
# case_00004: 100% 25269/25270 [00:00<00:00, 36349.19KB/s]
# Download 6/300:
# case_00005: 100% 313477/313478 [00:06<00:00, 51154.62KB/s]
# Download 7/300:
# case_00006: 100% 78010/78011 [00:01<00:00, 41692.18KB/s]
# Download 8/300:
# case_00007: 100% 25826/25827 [00:00<00:00, 39208.35KB/s]
# Download 9/300:
# case_00008: 100% 107068/107069 [00:02<00:00, 50904.27KB/s]
# Download 10/300:
# case_00009: 100% 34134/34135 [00:00<00:00, 40830.46KB/s]
# Download 11/300:
# case_00010: 100% 23541/23542 [00:00<00:00, 35812.85KB/s]
# Download 12/300:
# case_00011: 100% 41268/41269 [00:01<00:00, 23170.43KB/s]
# ...

# %%
# !mkdir imaging
# !mkdir segmentation
# !mkdir license

# %%
import shutil, os
files = ['data/LICENSE', 'data/kits.json']
for f in files:
    shutil.move(f, 'license')

# %%
import os
import nibabel as nib                                                                                                              

def list_files(dir): 
    i=-2
    j=-2                                                                                                
                                                                                                    
    subdirs = [x[0] for x in os.walk(dir)]                                                                            
    for subdir in subdirs:
        i=i+1 
        j=j+1                                                                                           
        files = os.walk(subdir).__next__()[2]                                                                             
        if (len(files) > 0):                                                                                          
            for file in files:              
              if file == 'segmentation.nii.gz':
                os.rename(subdir+'/'+file, 'segmentation/segmentation_' + str(i).zfill(3) + '.nii.gz')
              if file == 'imaging.nii.gz':
                os.rename(subdir+'/'+file, 'imaging/imaging_' + str(j).zfill(3) + '.nii.gz')

# %%
list_files('data/')

# %%
ls
# Out:
# drive/  kits19/  sample_data/

# %%
from kits19_utils import get_slices, save_slices, save_slices_all

# %%
cd kits19
# Out:
# /content/kits19

# %%
save_slices_all('imaging', 'imaging')

# %%
cd -

# %%
cd kits19

# %%
save_slices_all('segmentation', 'segmentation')

# %%
import shutil

# %%
shutil.make_archive('imaging_slices_zip', 'zip', 'kits19/imaging/imaging_slices')
#shutil.make_archive('segmentation_slices_zip', 'zip', 'segmentation/segmentation_slices')
# Out:
# '/content/imaging_slices_zip.zip'

# %%
# !cp -r 'imaging_slices_zip.zip' /content/drive/My\ Drive/Dane
#!cp -r 'segmentation_slices_zip.zip' /content/drive/My\ Drive/Dane
